# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
yang=pd.read_excel("양준혁.xlsx")

# %%
yang
# Out:
#       연도   팀  나이   P    G   타석   타수  득점   안타  2루타  ...  고의사구  삼진  병살타     타율  \
# 0   1993  삼성  24  1B  106  456  381  82  130   27  ...     6  40    7  0.341
# 1   1994  삼성  25  DH  123  496  427  62  128   21  ...     7  42    7  0.300
# 2   1995  삼성  26  LF  125  527  438  81  137   34  ...     8  50    7  0.313
# 3   1996  삼성  27  RF  126  530  436  89  151   33  ...     8  76    4  0.346
# 4   1997  삼성  28  RF  126  561  442  94  145   32  ...    27  75    7  0.328
# 5   1998  삼성  29  DH  126  552  456  80  156   30  ...    26  69   14  0.342
# 6   1999  해태  30  DH  131  588  496  96  160   23  ...     7  68   14  0.323
# 7   2000  LG  31  DH  117  514  432  79  135   30  ...     4  65    6  0.313
# 8   2001  LG  32  DH  124  531  439  79  156   20  ...     4  55    9  0.355
# 9   2002  삼성  33  RF  132  437  391  60  108   23  ...     3  56    9  0.276
# 10  2003  삼성  34  LF  133  551  490  90  161   37  ...     2  49   13  0.329
# ...

# %%
yang.describe()
# Out:
#                 연도         나이           G          타석          타수         득점  \
# count    18.000000  18.000000   18.000000   18.000000   18.000000  18.000000
# mean   2001.500000  32.500000  118.611111  489.277778  407.333333  72.166667
# std       5.338539   5.338539   18.163114  101.580339   85.921989  21.475704
# min    1993.000000  24.000000   64.000000  175.000000  142.000000  10.000000
# 25%    1997.250000  28.250000  118.500000  457.750000  391.750000  61.250000
# 50%    2001.500000  32.500000  124.500000  528.500000  434.000000  79.000000
# 75%    2005.750000  36.750000  126.000000  549.250000  442.000000  87.250000
# max    2010.000000  41.000000  133.000000  588.000000  496.000000  96.000000
#
#                안타        2루타        3루타         홈런  ...       고의사구         삼진  \
# count   18.000000  18.000000  18.000000  18.000000  ...  18.000000  18.000000
# mean   128.777778  25.444444   1.388889  19.500000  ...   8.333333  50.555556
# ...

# %%
yang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      18 non-null     int64
#  1   팀       18 non-null     object
#  2   나이      18 non-null     int64
#  3   P       18 non-null     object
#  4   G       18 non-null     int64
#  5   타석      18 non-null     int64
#  6   타수      18 non-null     int64
#  7   득점      18 non-null     int64
#  8   안타      18 non-null     int64
#  9   2루타     18 non-null     int64
#  10  3루타     18 non-null     int64
#  11  홈런      18 non-null     int64
#  12  루타      18 non-null     int64
#  13  타점      18 non-null     int64
#  14  도루      18 non-null     int64
#  15  도실      18 non-null     int64
#  16  볼넷      18 non-null     int64
#  17  사구      18 non-null     int64
#  18  고의사구    18 non-null     int64
#  19  삼진      18 non-null     int64
#  20  병살타     18 non-null     int64
# ...

# %%
yang2 = yang.set_index('연도')

# %%
yang2
# Out:
#        팀  나이   P    G   타석   타수  득점   안타  2루타  3루타  ...  고의사구  삼진  병살타     타율  \
# 연도                                                  ...
# 1993  삼성  24  1B  106  456  381  82  130   27    1  ...     6  40    7  0.341
# 1994  삼성  25  DH  123  496  427  62  128   21    1  ...     7  42    7  0.300
# 1995  삼성  26  LF  125  527  438  81  137   34    1  ...     8  50    7  0.313
# 1996  삼성  27  RF  126  530  436  89  151   33    2  ...     8  76    4  0.346
# 1997  삼성  28  RF  126  561  442  94  145   32    5  ...    27  75    7  0.328
# 1998  삼성  29  DH  126  552  456  80  156   30    1  ...    26  69   14  0.342
# 1999  해태  30  DH  131  588  496  96  160   23    1  ...     7  68   14  0.323
# 2000  LG  31  DH  117  514  432  79  135   30    2  ...     4  65    6  0.313
# 2001  LG  32  DH  124  531  439  79  156   20    3  ...     4  55    9  0.355
# 2002  삼성  33  RF  132  437  391  60  108   23    2  ...     3  56    9  0.276
# ...

# %%
rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False
yang2.타율.plot()
# Out:
# <AxesSubplot:xlabel='연도'>
