# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import glob

# %%
filenames = glob.glob("." + "/i_*.xlsx")

# %%
df = pd.DataFrame()
dfs = pd.DataFrame()
for f in filenames:
    df1 = pd.read_excel(f, skiprows=1)
    df1['name'] = f
    df = df.append(df1)
# Out:
# /Users/seunghoonyang/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /var/folders/09/nm0r299s3_x2gsjx08ww9l3w0000gn/T/ipykernel_79100/2224545340.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1)
# /Users/seunghoonyang/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /var/folders/09/nm0r299s3_x2gsjx08ww9l3w0000gn/T/ipykernel_79100/2224545340.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1)
# /Users/seunghoonyang/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /var/folders/09/nm0r299s3_x2gsjx08ww9l3w0000gn/T/ipykernel_79100/2224545340.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1)
# /Users/seunghoonyang/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /var/folders/09/nm0r299s3_x2gsjx08ww9l3w0000gn/T/ipykernel_79100/2224545340.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1)

# %%
df.columns
# Out:
# Index(['시점', '산업별(1)', '소계', '남', '여', '고졸', '고졸(여)', '전문학사', '전문학사(여)', '학사',
#        '학사(여)', '석사', '석사(여)', '박사', '박사(여)', '비이공계', '비이공계(여)', '공학계',
#        '공학계(여)', '자연계', '자연계(여)', '정규직', '정규직(여)', '비정규직', '비정규직(여)', '29세이하',
#        '29세이하(여)', '30~39세', '30~39세(여)', '30~49세', '30~49세(여)', '40~49세',
#        '40~49세(여)', '50대 이상', '50대 이상(여)', '50~59세', '50~59세(여)', '60대 이상',
#        '60대 이상(여)', '소계.1', '소계.2', '소계.3', '소계.4', '소계.5', 'name'],
#       dtype='object')

# %%
df.fillna(method = 'ffill', inplace=True)

# %%
df.to_excel('total_industry.xlsx')

# %%
total_industry = pd.read_excel('total_industry.xlsx', index_col=0)

# %%
total_industry
# Out:
#        시점             산업별(1)        소계         남        여       고졸   고졸(여)  \
# 0    2012                  계  233941.0  192524.0  41416.0  19540.0  3107.0
# 1    2012                 기계    2911.0    2812.0     99.0    952.0     0.0
# 2    2012              디스플레이      48.0      43.0      5.0      0.0     0.0
# 3    2012                반도체    2769.0    1901.0    867.0   1290.0   726.0
# 4    2012             바이오ㆍ헬스    1107.0     979.0    128.0    109.0    15.0
# ..    ...                ...       ...       ...      ...      ...     ...
# 289  2020         임대업; 부동산제외       NaN       NaN      NaN      NaN     NaN
# 290  2020  사업시설 관리 및 조경 서비스업     405.0     405.0      0.0    138.0     0.0
# 291  2020          사업지원 서비스업      57.0      57.0      0.0     29.0     0.0
# 292  2020             교육서비스업       5.0       5.0      0.0      0.0     0.0
# 293  2020                보건업     247.0     218.0     30.0     40.0     6.0
#
#         전문학사  전문학사(여)        학사  ...  50~59세  50~59세(여)  60대 이상  60대 이상(여)  \
# 0    48645.0   9623.0  138922.0  ...     NaN        NaN     NaN        NaN
# 1      833.0     28.0     844.0  ...     NaN        NaN     NaN        NaN
# 2        9.0      0.0      31.0  ...     NaN        NaN     NaN        NaN
# 3      285.0     30.0     824.0  ...     NaN        NaN     NaN        NaN
# 4      273.0     38.0     483.0  ...     NaN        NaN     NaN        NaN
# ..       ...      ...       ...  ...     ...        ...     ...        ...
# 289      NaN      NaN       NaN  ...     NaN        NaN     NaN        NaN
# 290     71.0      0.0     197.0  ...   131.0        0.0     0.0        0.0
# 291      0.0      0.0      28.0  ...    28.0        0.0     0.0        0.0
# 292      0.0      0.0       5.0  ...     0.0        0.0     0.0        0.0
# 293     64.0      1.0     134.0  ...    42.0        0.0     0.0        0.0
#
#      외국인인력  외국인인력(여)  직무3년차연봉  고용안전성  발전가능성  지역
# 0    438.0       NaN   3272.0    NaN    NaN  서울
# 1     23.0       NaN   3264.0    NaN    NaN  서울
# 2      0.0       NaN   9107.0    NaN    NaN  서울
# 3      9.0       NaN   3490.0    NaN    NaN  서울
# 4      0.0       NaN   3022.0    NaN    NaN  서울
# ..     ...       ...      ...    ...    ...  ..
# 289    NaN       NaN      NaN    NaN    NaN  울산
# 290    0.0       0.0   3804.0    4.7    4.6  울산
# 291    0.0       0.0   3398.0    4.0    4.0  울산
# 292    0.0       0.0   4700.0    4.0    4.0  울산
# 293    0.0       0.0   3845.0    3.7    3.7  울산
#
# [1232 rows x 45 columns]

# %%
from matplotlib import rc
rc('font', family='AppleGothic') 			## 이 두 줄을 
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# %%
total_industry = total_industry.assign(남성비율=total_industry.남/total_industry.소계,
                      여성비율=total_industry["학사(여)"] / total_industry.학사)

total_filter = total_industry.rename(columns={'산업별(1)':'산업별'}).\
                              query('산업별 in ["기계", "디스플레이", "반도체", "섬유", "자동차", "전자", "철강", "화학", "바이오ㆍ헬스"]')

# %%
sns.relplot(data = total_filter, x = '시점', y = '학사(여)', hue = '산업별', col='지역', kind = 'line')
