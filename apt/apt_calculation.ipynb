# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

# %%
apt_sale = pd.read_excel("apt_sale_total.xlsx", index_col='Unnamed: 0')

# %%
apt_rent = pd.read_excel("apt_rent_total.xlsx", index_col='Unnamed: 0')

# %%
apt_rent.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전월세구분', '전용면적(㎡)', '계약년월', '계약일',
#        '보증금(만원)', '월세(만원)', '층', '건축년도', '도로명', '계약기간', '계약구분', '갱신요구권 사용',
#        '종전계약 보증금 (만원)', '종전계약 월세 (만원)'],
#       dtype='object')

# %%
apt_sale.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명', '해제사유발생일', '거래유형', '중개사소재지', '거래금액'],
#       dtype='object')

# %%
apt_sale.head(1)
# Out:
#                시군구   번지   본번  부번         단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.93  200601   17
#
#          거래금액(만원)  층  건축년도      도로명  해제사유발생일 거래유형 중개사소재지   거래금액
# 0          21,500  7  2000  증가로 191      NaN    -      -  21500

# %%
apt_rent.head(1)
# Out:
#                시군구   번지   본번  부번         단지명 전월세구분  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    전세    59.97  201101    3
#
#           보증금(만원)  월세(만원)     층  건축년도      도로명 계약기간 계약구분 갱신요구권 사용  \
# 0          17,000       0  12.0  2000  증가로 191    -    -        -
#
#   종전계약 보증금 (만원) 종전계약 월세 (만원)
# 0

# %%
apt_total = pd.concat([apt_sale, apt_rent])

# %%
apt_total.to_excel("apt_total.xlsx")

# %%
apt_sale["구분"]="매매"

# %%
apt_sale
# Out:
#                    시군구     번지   본번  부번         단지명  전용면적(㎡)    계약년월  계약일  \
# 0      서울특별시 서대문구 남가좌동    377  377   0  DMC래미안클라시스    59.93  200601   17
# 1      서울특별시 서대문구 남가좌동    377  377   0  DMC래미안클라시스    84.90  200601   22
# 2      서울특별시 서대문구 남가좌동    377  377   0  DMC래미안클라시스    59.59  200601   25
# 3      서울특별시 서대문구 남가좌동    377  377   0  DMC래미안클라시스    59.59  200602   14
# 4      서울특별시 서대문구 남가좌동    377  377   0  DMC래미안클라시스    84.90  200602   14
# ...                ...    ...  ...  ..         ...      ...     ...  ...
# 35421   서울특별시 서대문구 홍제동    331  331   0        홍제현대    60.81  202112   11
# 35422   서울특별시 서대문구 홍제동  346-7  346   7          힐탑    27.96  202106   23
# 35423   서울특별시 서대문구 홍제동  346-7  346   7          힐탑    27.96  202106   23
# 35424   서울특별시 서대문구 홍제동  346-7  346   7          힐탑    40.66  202106   24
# 35425   서울특별시 서대문구 홍제동  346-7  346   7          힐탑    31.00  202106   24
#
#              거래금액(만원)   층  건축년도         도로명  해제사유발생일  거래유형   중개사소재지   거래금액  구분
# ...

# %%
apt_rent.rename(columns={"전월세구분":"구분"}, inplace=True)

# %%
apt_total = pd.concat([apt_sale, apt_rent])

# %%
apt_total.to_excel("apt_total.xlsx")

# %%
apt_total
# Out:
#                    시군구   번지   본번  부번         단지명  전용면적(㎡)    계약년월  계약일  \
# 0      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.93  200601   17
# 1      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    84.90  200601   22
# 2      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.59  200601   25
# 3      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.59  200602   14
# 4      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    84.90  200602   14
# ...                ...  ...  ...  ..         ...      ...     ...  ...
# 46364   서울특별시 서대문구 홍제동  331  331   0        홍제현대    75.15  202203    4
# 46365   서울특별시 서대문구 홍제동  331  331   0        홍제현대    75.15  202203    5
# 46366   서울특별시 서대문구 홍제동  331  331   0        홍제현대    83.05  202203    7
# 46367   서울특별시 서대문구 홍제동  331  331   0        홍제현대    75.15  202203   18
# 46368   서울특별시 서대문구 홍제동  331  331   0        홍제현대   106.18  202203   26
#
#              거래금액(만원)     층  ...  중개사소재지     거래금액  구분         보증금(만원) 월세(만원)  \
# ...

# %%
def day_parser(x):
    if len(str(x)) == 1:
        return "0"+str(x)
    else:
        return x

# %%
apt_total["계약일"].map(day_parser)
# Out:
# 0        17
# 1        22
# 2        25
# 3        14
# 4        14
#          ..
# 46364    04
# 46365    05
# 46366    07
# 46367    18
# 46368    26
# Name: 계약일, Length: 81795, dtype: object

# %%
apt_total["계약일"] = apt_total["계약일"].map(day_parser)

# %%
apt_total.계약일.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 81795 entries, 0 to 46368
# Series name: 계약일
# Non-Null Count  Dtype
# --------------  -----
# 81795 non-null  object
# dtypes: object(1)
# memory usage: 1.2+ MB

# %%
apt_total.ymd
# Out:
# '0        200601\n1        200601\n2        200601\n3        200602\n4        200602\n          ...  \n46364    202203\n46365    202203\n46366    202203\n46367    202203\n46368    202203\nName: 계약년월, Length: 81795, dtype: int64'

# %%
apt_total.head()
# Out:
#                시군구   번지   본번  부번         단지명  전용면적(㎡)    계약년월 계약일  \
# 0  서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.93  200601  17
# 1  서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    84.90  200601  22
# 2  서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.59  200601  25
# 3  서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.59  200602  14
# 4  서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    84.90  200602  14
#
#          거래금액(만원)     층  ...     거래금액  구분  보증금(만원) 월세(만원) 계약기간  계약구분 갱신요구권 사용  \
# 0          21,500   7.0  ...  21500.0  매매      NaN    NaN  NaN   NaN      NaN
# 1          30,350  11.0  ...  30350.0  매매      NaN    NaN  NaN   NaN      NaN
# 2          20,200   9.0  ...  20200.0  매매      NaN    NaN  NaN   NaN      NaN
# 3          21,000  10.0  ...  21000.0  매매      NaN    NaN  NaN   NaN      NaN
# 4          28,000   5.0  ...  28000.0  매매      NaN    NaN  NaN   NaN      NaN
#
#   종전계약 보증금 (만원)  종전계약 월세 (만원)  \
# 0           NaN           NaN
# 1           NaN           NaN
# ...

# %%
apt_total.loc[:, ["계약년월", "계약일", "ymd"]]
# Out:
#          계약년월 계약일                                                ymd
# 0      200601  17  0        200601\n1        200601\n2        200...
# 1      200601  22  0        200601\n1        200601\n2        200...
# 2      200601  25  0        200601\n1        200601\n2        200...
# 3      200602  14  0        200601\n1        200601\n2        200...
# 4      200602  14  0        200601\n1        200601\n2        200...
# ...       ...  ..                                                ...
# 46364  202203  04  0        200601\n1        200601\n2        200...
# 46365  202203  05  0        200601\n1        200601\n2        200...
# 46366  202203  07  0        200601\n1        200601\n2        200...
# 46367  202203  18  0        200601\n1        200601\n2        200...
# 46368  202203  26  0        200601\n1        200601\n2        200...
#
# [81795 rows x 3 columns]

# %%
apt_total.drop('ymd', axis=1, inplace=True)

# %%
import datetime

# %%
apt_total['ymd'] = apt_total.계약년월.astype('str') + apt_total.계약일.astype('str')

# %%
apt_total['ymd'] = pd.to_datetime(apt_total['ymd'])

# %%
apt_total
# Out:
#                    시군구   번지   본번  부번         단지명  전용면적(㎡)    계약년월 계약일  \
# 0      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.93  200601  17
# 1      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    84.90  200601  22
# 2      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.59  200601  25
# 3      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    59.59  200602  14
# 4      서울특별시 서대문구 남가좌동  377  377   0  DMC래미안클라시스    84.90  200602  14
# ...                ...  ...  ...  ..         ...      ...     ...  ..
# 46364   서울특별시 서대문구 홍제동  331  331   0        홍제현대    75.15  202203  04
# 46365   서울특별시 서대문구 홍제동  331  331   0        홍제현대    75.15  202203  05
# 46366   서울특별시 서대문구 홍제동  331  331   0        홍제현대    83.05  202203  07
# 46367   서울특별시 서대문구 홍제동  331  331   0        홍제현대    75.15  202203  18
# 46368   서울특별시 서대문구 홍제동  331  331   0        홍제현대   106.18  202203  26
#
#              거래금액(만원)     층  ...     거래금액  구분         보증금(만원) 월세(만원) 계약기간  \
# ...

# %%
sns.lineplot(x = 'ymd', y = '거래금액', hue = '단지명', data = apt_total[apt_total['단지명'].isin(['홍제한양', '홍제현대'])])
# Out:
# <AxesSubplot:xlabel='ymd', ylabel='거래금액'>

# %%
g = sns.FacetGrid(data = apt_total[apt_total['단지명'].isin(['홍제한양', '홍제현대'])], col='단지명', hue='전용면적(㎡)')
g.map_dataframe(sns.lineplot, x = 'ymd', y = '거래금액')
plt.gcf().set_size_inches(15, 8)
g.add_legend()
