# %%
#init packages
import pandas as pd
import numpy as np
from io import StringIO
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
from pdfminer.converter import TextConverter
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter

# %%
#parsing pdf
def read_pdf(file_name):
    output_string = StringIO()
    with open(file_name, 'rb') as f:
        parser = PDFParser(f)
        doc = PDFDocument(parser)
        rsrcmgr = PDFResourceManager()

        device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.create_pages(doc):
            interpreter.process_page(page)

    return output_string.getvalue()

string_df = pd.DataFrame(None)

# %%
os.listdir()[2]
# Out:
# '국회공보+제2022-31호(정기재산변동신고).pdf'

# %%
pdf_file = read_pdf(os.listdir()[2])

# %%
import tabula

# %%
os.listdir()[2]
# Out:
# '국회공보+제2022-31호(정기재산변동신고).pdf'

# %%
df =tabula.read_pdf(os.listdir()[2], pages='all')

# %%
df
# Out:
# [Empty DataFrame
#  Columns: [국 회 공 보]
#  Index: [],
#            소속 Unnamed: 0                                  국회       직위  \
#  0        NaN        NaN                                 NaN      NaN
#  1        NaN        NaN                                 NaN      NaN
#  2       본인과의        NaN                                 NaN      NaN
#  3     재산의 종류        NaN                     소재지 면적 등 권리의 명세     종전가액
#  4         관계        NaN                                 NaN      NaN
#  5        NaN        NaN                                 NaN      NaN
#  6   ▶ 토지(소계)        NaN                                 NaN  330,544
#  7        NaN        NaN  충청북도 제천시 봉양읍 연박리 산 176번지 44,826.00      NaN
#  8         본인         임야                                 NaN   46,170
#  9        NaN        NaN                                  m2      NaN
#  10       NaN        NaN          충청북도 제천시 봉양읍 연박리 산 184-1번지      NaN
#  11        본인         임야                                 NaN  111,452
#  12       NaN        NaN                        114,545.00m2      NaN
#  13       NaN        NaN  충청북도 제천시 봉양읍 연박리 산 185번지 30,942.00      NaN
#  14        본인         임야                                 NaN   33,417
#  15       NaN        NaN                                  m2      NaN
#
#                 국회의장               성명  박병석 Unnamed: 1
#  0               NaN              NaN  NaN  (단위 : 천원)
#  1               변동액              NaN  NaN        NaN
#  2               NaN              NaN  NaN        NaN
#  3               NaN        현재가액 변동사유  NaN        NaN
#  4           증가액 감소액              NaN  NaN        NaN
#  5   (실거래가격) (실거래가격)              NaN  NaN        NaN
#  6          15,168 0          345,712  NaN        NaN
#  7               NaN              NaN  NaN        NaN
#  8           4,035 0   50,205 공시지가 증가  NaN        NaN
#  9               NaN              NaN  NaN        NaN
#  10              NaN              NaN  NaN        NaN
#  11          6,529 0  117,981 공시지가 증가  NaN        NaN
#  12              NaN              NaN  NaN        NaN
#  13              NaN              NaN  NaN        NaN
#  14          2,785 0   36,202 공시지가 증가  NaN        NaN
#  15              NaN              NaN  NaN        NaN  ,
#                                             본인 대지  \
#  0                                          본인 대지
#  1                                          본인 대지
#  2                                          본인 대지
#  3                                       ▶ 건물(소계)
#  4                                         본인 아파트
#  5                                          본인 창고
#  6                                       사무실(전세(임
#  7                                             본인
#  8                                           차)권)
#  9     아파트(전세(임 서울특별시 용산구 이촌동 타워맨션 건물 202.45m2 (건
#  10                                            본인
#  11                                          차)권)
#  12  ▶ 부동산에 관한 규정이 준용되는 권리와 자동차·건설기계·선박 및 항공기(소계)
#  13                                           NaN
#  14                                        본인 자동차
#  15                                           NaN
#  16                                           NaN
#  17                                        본인 자동차
#  18                                           NaN
#  19                                      ▶ 예금(소계)
#  20                                           NaN
#  21                                           NaN
#  22                                            본인
#  23                                           NaN
#  24                                           NaN
#  25                                           NaN
#  26                                           NaN
#  27                                           NaN
#  28                                           배우자
#  29                                           NaN
#
#                충청북도 제천시 봉양읍 원박리 500번지 264.00m2  Unnamed: 0     11,140  \
#  0            충청북도 제천시 봉양읍 원박리 500-1번지 37.00m2         NaN      1,561
#  1             충청북도 제천시 봉양읍 원박리 515번지 142.00m2         NaN      5,992
#  2                대전광역시 동구 중동 35-10번지 148.60m2         NaN    120,812
#  3                                         NaN         NaN  4,225,943
#  4             서울특별시 서초구 반포동 반포아파트 건물 196.80m2         NaN  3,961,000
#  5          대전광역시 동구 중동 대지 317.40m2 건물 56.30m2         NaN    234,943
#  6                                         NaN         NaN        NaN
#  7                    대전광역시 서구 도마동 건물 132.00m2         NaN     30,000
#  8                                         NaN         NaN        NaN
#  9                                         NaN         NaN        NaN
#  10                                        NaN         NaN          0
#  11                             물 202.45m2 증가)         NaN        NaN
#  12                                        NaN         NaN     35,240
#  13                                        NaN         NaN        NaN
#  14                 2006년식 그랜저 배기량(3,342cc) 감소         NaN      4,440
#  15                                        NaN         NaN        NaN
#  16                                        NaN         NaN        NaN
#  17                 2015년식 에쿠스 배기량(3,778cc) 감소         NaN     30,800
#  18                                        NaN         NaN        NaN
#  19                                        NaN         NaN  1,603,266
#  20         (주)KEB하나은행 58,999(11,758 증가), 국민은행         NaN        NaN
#  21  26,305(1,269,392 감소), 농협은행 21,000(7,000 증         NaN        NaN
#  22                                        NaN         NaN  1,394,554
#  23          가), 미래에셋생명보험 37,510, 새마을금고 44(1 증         NaN        NaN
#  24                           가), 신용협동조합중앙회 63         NaN        NaN
#  25                                        NaN         NaN        NaN
#  26                                        NaN         NaN        NaN
#  27             KB생명보험 60,000(53,000 감소), 국민은행         NaN        NaN
#  28      151,088(55,438 증가), 메리츠종금증권 33, 스탠다드차         NaN    208,712
#  29                            타드은행 9, 신한은행 20         NaN        NaN
#
#            819          0     11,959 공시지가 증가
#  0         115          0      1,676 공시지가 증가
#  1         440          0      6,432 공시지가 증가
#  2         445          0    121,257 공시지가 증가
#  3   1,617,187          0          5,843,130
#  4     165,000          0  4,126,000 공시가격 증가
#  5      52,187          0    287,130 공시가격 증가
#  6         NaN        NaN                NaN
#  7           0          0        30,000 변동없음
#  8         NaN        NaN                NaN
#  9         NaN        NaN                NaN
#  10  1,400,000          0  1,400,000 전세권(신규)
#  11        NaN        NaN                NaN
#  12          0     35,240                  0
#  13        NaN      4,440                NaN
#  14          0        NaN               0 매도
#  15        NaN    (1,500)                NaN
#  16        NaN     30,800                NaN
#  17          0        NaN               0 매도
#  18        NaN   (16,000)                NaN
#  19    140,327  1,388,522            355,071
#  20        NaN        NaN                NaN
#  21        NaN        NaN                NaN
#  22     29,107  1,279,740            143,921
#  23        NaN        NaN                NaN
#  24        NaN        NaN                NaN
#  25        NaN        NaN    -전세보증금 및 생활비 사용
#  26        NaN        NaN              -급여저축
#  27        NaN        NaN                NaN
#  28    111,220    108,782            211,150
#  29        NaN        NaN                NaN  ,
#    ▶ 정치자금법에 따른 정치자금의 수입 및 지출을 위한 예금계좌의 예금(소계)    113,497  \
#  0                                         본인        NaN
#  1                                  ▶ 회원권(소계)     18,000
#  2                                         본인         헬스
#  3                            ▶ 고지거부 및 등록제외사항          -
#  4                                         장남        NaN
#  5                                         차남        NaN
#  6                                        총 계  6,326,490
#
#                         0     53,921     59,576  \
#  0  우체국 59,576(53,921 감소)    113,497          0
#  1                      0          0     18,000
#  2       한화개발(주)프라자휘트니스클럽     18,000          0
#  3                      -          -          -
#  4                   고지거부          0          0
#  5                   고지거부          0          0
#  6              1,772,682  1,477,683  6,621,489
#
#                            Unnamed: 0 Unnamed: 1 Unnamed: 2
#  0                             53,921     59,576    정치자금 감소
#  1                                NaN        NaN        NaN
#  2                                  0     18,000       변동없음
#  3                                NaN        NaN        NaN
#  4                                  0          0     독립생계유지
#  5                                  0          0     독립생계유지
#  6  증감액: 294,999천원\r(가액변동: 232,355천원)        NaN        NaN  ,
#  Empty DataFrame
#  Columns: [- 3, -]
#  Index: [],
#                                                소속  \
#  0                                            NaN
#  1                                            NaN
#  2                                           본인과의
#  3                                         재산의 종류
#  4                                             관계
#  5                                            NaN
#  6                                       ▶ 토지(소계)
#  7                                            NaN
#  8                                         배우자 임야
#  9                                            NaN
#  10                                      ▶ 건물(소계)
#  11                                        본인 아파트
#  12  ▶ 부동산에 관한 규정이 준용되는 권리와 자동차·건설기계·선박 및 항공기(소계)
#  13                                       배우자 자동차
#  14                                      ▶ 예금(소계)
#  15                                           NaN
#  16                                           NaN
#  17                                           NaN
#  18                                           NaN
#  19                                            본인
#  20                                           NaN
#  21                                           NaN
#  22                                           NaN
#  23                                           NaN
#
#                                            국회  Unnamed: 0       직위  \
#  0                                        NaN         NaN      NaN
#  1                                        NaN         NaN      NaN
#  2                                        NaN         NaN      NaN
#  3                            소재지 면적 등 권리의 명세         NaN     종전가액
#  4                                        NaN         NaN      NaN
#  5                                        NaN         NaN      NaN
#  6                                        NaN         NaN    5,920
#  7        전라북도 완주군 구이면 광곡리 산 44번지 18,050.00m2         NaN      NaN
#  8                                        NaN         NaN    5,920
#  9                               중 3,610.00m2         NaN      NaN
#  10                                       NaN         NaN  251,000
#  11            경기도 부천시 소사본동 두산아파트 건물 101.82m2         NaN  251,000
#  12                                       NaN         NaN    7,413
#  13           2012년식 yf 소나타 cvvl 배기량(1,999cc)         NaN    7,413
#  14                                       NaN         NaN  775,606
#  15        NH투자증권 130,152(130,152 증가), 교보생명보험         NaN      NaN
#  16   55,200, 농협은행 131,824(27,771 증가), 미래에셋대우         NaN      NaN
#  17            (주) 257,749(59,561 증가), 삼성생명보험         NaN      NaN
#  18   29,577(1,724 증가), 새마을금고 146(146 증가), 새마         NaN      NaN
#  19                                       NaN         NaN  419,606
#  20            을금고중앙회 공제사업부 11,453, 신용협동조합중앙회         NaN      NaN
#  21  10,821(4 증가), 신한은행 10,346(1,696 감소), 케이뱅         NaN      NaN
#  22  크 500(500 증가), 한국포스증권(주) 52,060(52,060 증         NaN      NaN
#  23                                        가)         NaN      NaN
#
#                국회부의장            성명   김상희 Unnamed: 1
#  0               NaN           NaN   NaN  (단위 : 천원)
#  1               변동액           NaN   NaN        NaN
#  2               NaN           NaN   NaN        NaN
#  3               NaN          현재가액  변동사유        NaN
#  4           증가액 감소액           NaN   NaN        NaN
#  5   (실거래가격) (실거래가격)           NaN   NaN        NaN
#  6             361 0         6,281   NaN        NaN
#  7               NaN           NaN   NaN        NaN
#  8             361 0    6,281 가액변동   NaN        NaN
#  9               NaN           NaN   NaN        NaN
#  10         42,000 0       293,000   NaN        NaN
#  11         42,000 0  293,000 가액변동   NaN        NaN
#  12            0 678         6,735   NaN        NaN
#  13            0 678    6,735 가액변동   NaN        NaN
#  14  310,670 118,993       967,283   NaN        NaN
#  15              NaN           NaN   NaN        NaN
#  16              NaN           NaN   NaN        NaN
#  17              NaN           NaN   NaN        NaN
#  18              NaN           NaN   NaN        NaN
#  19   281,824 11,602  689,828 급여저축   NaN        NaN
#  20              NaN           NaN   NaN        NaN
#  21              NaN           NaN   NaN        NaN
#  22              NaN           NaN   NaN        NaN
#  23              NaN           NaN   NaN        NaN  ,
#                                            배우자 Unnamed: 0  \
#  0  ▶ 정치자금법에 따른 정치자금의 수입 및 지출을 위한 예금계좌의 예금(소계)    170,069
#  1                                          본인        NaN
#  2                             ▶ 고지거부 및 등록제외사항          -
#  3                                          장남        NaN
#  4                                         총 계  1,496,061
#
#    AIA생명보험주식회사 16,317(1,280 증가), 국민은행\r140,088(84,701 감소), 미래에셋대우(주) 280(267 증\r가), 신한은행 28(249 감소), 우체국 4,536, 하나손해\r보험(주) 56,000(12,000 증가), 한국교직원공제회\r60,206(7,142 감소)  \
#  0                                                  0
#  1                             농협은행 92,212(77,857 감소)
#  2                                                  -
#  3                                               고지거부
#  4                                            353,031
#
#     356,000     28,846                            107,391 277,455 급여저축 및 생활비 지출
#  0   77,857     92,212                                NaN     NaN           NaN
#  1  170,069          0                             77,857  92,212       정치자금 사용
#  2        -          -                                NaN     NaN           NaN
#  3  286,053          0                            286,053       0        독립생계유지
#  4  483,581  1,365,511  증감액: -130,550천원\r(가액변동: 41,683천원)     NaN           NaN  ,
#  Empty DataFrame
#  Columns: [- 5, -]
#  Index: [],
#                                                소속  \
#  0                                            NaN
#  1                                            NaN
#  2                                           본인과의
#  3                                         재산의 종류
#  4                                             관계
#  5                                            NaN
#  6                                       ▶ 토지(소계)
#  7                                          본인 임야
#  8                                            NaN
#  9                                         배우자 임야
#  10                                           NaN
#  11                                      ▶ 건물(소계)
#  12                                           NaN
#  13                                        본인 아파트
#  14                                           NaN
#  15                                      사무실(전세(임
#  16                                            본인
#  17                                          차)권)
#  18                                           NaN
#  19                                       배우자 아파트
#  20                                           NaN
#  21         아파트(전세(임 서울특별시 강남구 도곡동 로덴하우스 웨스트빌리지 건
#  22                                           배우자
#  23                                          차)권)
#  24     아파트(전세(임 충청남도 공주시 신관동 삼환나우빌 건물 0.00m2 (건물
#  25                                           배우자
#  26                                          차)권)
#  27    아파트(전세(임 충청남도 공주시 신관동 삼환나우빌 건물 119.68m2 (건
#  28                                           배우자
#  29                                          차)권)
#  30  ▶ 부동산에 관한 규정이 준용되는 권리와 자동차·건설기계·선박 및 항공기(소계)
#  31                                        본인 자동차
#  32                                           NaN
#  33                                        본인 자동차
#  34                                           NaN
#
#                                        국회  Unnamed: 0         직위  \
#  0                                    NaN         NaN        NaN
#  1                                    NaN         NaN        NaN
#  2                                    NaN         NaN        NaN
#  3                        소재지 면적 등 권리의 명세         NaN       종전가액
#  4                                    NaN         NaN        NaN
#  5                                    NaN         NaN        NaN
#  6                                    NaN         NaN    814,820
#  7    충청북도 충주시 노은면 가신리 산 13번지 20,231.00m2         NaN     31,156
#  8   서울특별시 강남구 도곡동 산 32-1번지 17,094.00m2 중         NaN        NaN
#  9                                    NaN         NaN    783,664
#  10                            1,899.33m2         NaN        NaN
#  11                                   NaN         NaN  5,910,000
#  12       서울특별시 강남구 압구정동 신현대아파트 건물 183.41         NaN        NaN
#  13                                   NaN         NaN  1,600,000
#  14                          m2 중 91.70m2         NaN        NaN
#  15                                   NaN         NaN        NaN
#  16              충청남도 공주시 신관동 건물 106.14m2         NaN     30,000
#  17                                   NaN         NaN        NaN
#  18       서울특별시 강남구 압구정동 신현대아파트 건물 183.41         NaN        NaN
#  19                                   NaN         NaN  1,600,000
#  20                          m2 중 91.70m2         NaN        NaN
#  21                                   NaN         NaN        NaN
#  22                                   NaN         NaN  2,500,000
#  23                            물 244.66m2         NaN        NaN
#  24                                   NaN         NaN        NaN
#  25                                   NaN         NaN    180,000
#  26                          119.68m2 감소)         NaN        NaN
#  27                                   NaN         NaN        NaN
#  28                                   NaN         NaN          0
#  29                        물 119.68m2 증가)         NaN        NaN
#  30                                   NaN         NaN    106,870
#  31         2011년식 에쿠스 VS500 배기량(5,000cc)         NaN     24,130
#  32                                   NaN         NaN        NaN
#  33           2010년식 제네시스 배기량(3,342cc) 감소         NaN      8,510
#  34                                   NaN         NaN        NaN
#
#                국회부의장              성명 정진석  Unnamed: 1 Unnamed: 2
#  0               NaN                 NaN         NaN  (단위 : 천원)
#  1               변동액                 NaN         NaN        NaN
#  2               NaN                 NaN         NaN        NaN
#  3               NaN           현재가액 변동사유         NaN        NaN
#  4           증가액 감소액                 NaN         NaN        NaN
#  5   (실거래가격) (실거래가격)                 NaN         NaN        NaN
#  6          83,717 0             898,537         NaN        NaN
#  7           2,427 0         33,583 가액변동         NaN        NaN
#  8               NaN                 NaN         NaN        NaN
#  9          81,290 0        864,954 가액변동         NaN        NaN
#  10              NaN                 NaN         NaN        NaN
#  11  710,000 180,000           6,440,000         NaN        NaN
#  12              NaN                 NaN         NaN        NaN
#  13        245,000 0      1,845,000 가액변동         NaN        NaN
#  14              NaN                 NaN         NaN        NaN
#  15              NaN                 NaN         NaN        NaN
#  16              0 0  30,000 변동없음(지역사무실)         NaN        NaN
#  17              NaN                 NaN         NaN        NaN
#  18              NaN                 NaN         NaN        NaN
#  19        245,000 0      1,845,000 가액변동         NaN        NaN
#  20              NaN                 NaN         NaN        NaN
#  21              NaN                 NaN         NaN        NaN
#  22              0 0      2,500,000 변동없음         NaN        NaN
#  23              NaN                 NaN         NaN        NaN
#  24              NaN                 NaN         NaN        NaN
#  25        0 180,000              0 계약만료         NaN        NaN
#  26              NaN                 NaN         NaN        NaN
#  27              NaN                 NaN         NaN        NaN
#  28        220,000 0      220,000 신규전세계약         NaN        NaN
#  29              NaN                 NaN         NaN        NaN
#  30         0 24,780              82,090         NaN        NaN
#  31          0 1,300         22,830 가액변동         NaN        NaN
#  32            8,510                 NaN         NaN        NaN
#  33                0                0 매도         NaN        NaN
#  34         (10,000)                 NaN         NaN        NaN  ,
#                                            배우자        자동차  \
#  0                                          차녀        자동차
#  1                                    ▶ 예금(소계)  1,220,958
#  2                                          본인        NaN
#  3                                         배우자        NaN
#  4                                          차녀        NaN
#  5  ▶ 정치자금법에 따른 정치자금의 수입 및 지출을 위한 예금계좌의 예금(소계)    135,357
#  6                                          본인        NaN
#  7                                    ▶ 증권(소계)    274,883
#
#                              2020년식 GV80 배기량(2,497cc)   37,115          0  \
#  0                           2020년식 GV80 배기량(2,497cc)   37,115          0
#  1                                            667,101  556,543  1,331,516
#  2  (주)KEB하나은행 122,568(77,079 증가), 교보생명보험\r55,051(...  253,480    142,317
#  3  (주)KEB하나은행 176,413(198,436 감소), AIA생명보험\r주식회사 ...  651,737    471,755
#  4  (주)KEB하나은행 221,760(4,924 감소), 국민은행\r50,582(50,...  315,741     53,029
#  5                                              1,429        0    136,786
#  6                            농협중앙회 136,786(1,429 증가)  135,357      1,429
#  7                                            294,200  249,568    319,515
#
#       7,485   29,630    가액변동
#  0    7,485   29,630    가액변동
#  1      NaN      NaN     NaN
#  2   61,784  334,013    급여 등
#  3  437,451  686,041     NaN
#  4   57,308  311,462     NaN
#  5      NaN      NaN     NaN
#  6        0  136,786  후원금 증가
#  7      NaN      NaN     NaN  ,
#  Empty DataFrame
#  Columns: [- 7, -]
#  Index: [],
#           Unnamed: 0  Unnamed: 1 POSCO 86주(86주 증가), POSCO 0주(86주 감소), SK바이  \
#  0               NaN         NaN        오사이언스 4주(4주 증가), SK이노베이션 460주(460주
#  1               NaN         NaN       증가), SK이노베이션 0주(460주 감소), 에스피지 100주
#  2          배우자 상장주식         NaN                                       NaN
#  3               NaN         NaN        (100주 증가), 에스피지 0주(100주 감소), 코리아로터
#  4               NaN         NaN     리 726주(726주 증가), 현대차 700주(700주 증가), 현
#  5               NaN         NaN                                       NaN
#  6               NaN         NaN                            대차 0주(700주 감소)
#  7         배우자 비상장주식         NaN                        코리아로터리 0주(726주 감소)
#  8           차녀 상장주식         NaN       SK이노베이션 55주, 에스피지 1,759주, 엔터메이트 54주
#  9          ▶ 채무(소계)         NaN                                       NaN
#  10        본인 건물임대채무         NaN               서울특별시 강남구 압구정동 신현대아파트 임대보증금
#  11       배우자 건물임대채무         NaN               서울특별시 강남구 압구정동 신현대아파트 임대보증금
#  12        ▶ 회원권(소계)         NaN                                       NaN
#  13           배우자 헬스         NaN                                      신라호텔
#  14  ▶ 비영리법인에 출연한 재산         NaN                                       NaN
#  15              NaN         NaN        (재)계룡장학회, 출연재산: 300,000천원, 보유직위: 이
#  16           배우자 출연         NaN                                       NaN
#  17              NaN         NaN                                        사장
#  18              NaN         NaN                                       NaN
#  19              NaN         NaN                                       총 계
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4                   Unnamed: 5
#  0         NaN        NaN        NaN                          NaN
#  1         NaN        NaN        NaN                          NaN
#  2     246,023    285,306    246,023                      285,306
#  3         NaN        NaN        NaN                          NaN
#  4         NaN        NaN        NaN                          NaN
#  5         NaN        NaN        NaN               가액변동 및 신규주식 매입
#  6         NaN        NaN        NaN                          NaN
#  7       3,365          0      3,365                            0
#  8      25,495      8,894        180                       34,209
#  9   1,260,000          0          0                    1,260,000
#  10    630,000          0          0                 630,000 변동없음
#  11    630,000          0          0                 630,000 변동없음
#  12     80,000          0          0                       80,000
#  13     80,000          0          0                  80,000 변동없음
#  14          -          -          -                            -
#  15        NaN        NaN        NaN                          NaN
#  16          -          -          -                       - 변동없음
#  17        NaN        NaN        NaN                          NaN
#  18        NaN        NaN        NaN               증감액: 745,556천원
#  19  7,282,888  1,756,447  1,010,891  8,028,444 (가액변동: 566,161천원)  ,
#            소속      Unnamed: 0  \
#  0        NaN             NaN
#  1   (단위 : 천원             NaN
#  2   본인과의\r관계          재산의 종류
#  3        NaN             NaN
#  4   ▶ 토지(소계)       2,383,560
#  5         본인              대지
#  6         본인             과수원
#  7        배우자              임야
#  8        배우자             과수원
#  9        배우자              임야
#  10       배우자              임야
#  11       배우자              임야
#  12        장남               답
#  13        장남               답
#  14  ▶ 건물(소계)       3,786,420
#  15        본인  아파트(전세(임\r차)권)
#
#                                             Unnamed: 1    Unnamed: 2  \
#  0                                                 NaN           NaN
#  1                                                 NaN           NaN
#  2                                     소재지 면적 등 권리의 명세          종전가액
#  3                                                 NaN  증가액\r(실거래가격)
#  4                                              65,140     1,052,586
#  5                    경상남도 창원시 성산구 사파동 62-7번지 312.70m2       372,113
#  6     경상남도 창원시 성산구 사파정동 152번지 0.00m2\r(7,036.00m2 감소)     1,052,586
#  7               경상남도 창원시 성산구 사파정동 산 78번지 6,248.00\rm2        40,362
#  8                 경상남도 창원시 성산구 사파정동 24-1번지 3,691.00m2       455,839
#  9              경상남도 창원시 성산구 사파정동 산 82-7번지\r8,186.00m2        72,201
#  10              경상남도 창원시 성산구 사파정동 산 82-8번지 726.00\rm2         7,841
#  11             경상남도 창원시 성산구 사파정동 산 72번지 10,810.10\rm2        17,188
#  12                 경상남도 창원시 성산구 삼정자동 522-1번지 440.00m2       140,700
#  13                 경상남도 창원시 성산구 삼정자동 522-8번지 701.00m2       224,730
#  14                                             50,245       187,449
#  15  경상남도 창원시 성산구 사파동 사파동성아파트 건물\r0.00m2 (건물 133.56...       150,000
#
#        Unnamed: 3              Unnamed: 4 Unnamed: 5  \
#  0            NaN                     NaN        NaN
#  1            NaN                     NaN        NaN
#  2            변동액                    현재가액       변동사유
#  3   감소액\r(실거래가격)                     NaN        NaN
#  4      1,396,114                     NaN        NaN
#  5          9,381                       0    381,494
#  6              0  1,052,586\r(4,200,000)          0
#  7          3,749                       0     44,111
#  8         40,231                       0    496,070
#  9          9,250                       0     81,451
#  10         1,016                       0      8,857
#  11         1,513                       0     18,701
#  12             0                       0    140,700
#  13             0                       0    224,730
#  14     3,649,216                     NaN        NaN
#  15             0                 150,000          0
#
#                                             Unnamed: 6
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                가액변동
#  6   가음정근린공원 조성사업으로 인한\r토지수용으로 매도(토지보상금 약42\r억 중 양도...
#  7                                                가액변동
#  8                                                가액변동
#  9                                                가액변동
#  10                                               가액변동
#  11                                               가액변동
#  12                                            가액변동 없음
#  13                                            가액변동 없음
#  14                                                NaN
#  15                                            전세계약 해지  ,
#  Empty DataFrame
#  Columns: [- 9, -]
#  Index: [],
#  Empty DataFrame
#  Columns: [- 10, Unnamed: 0]
#  Index: [],
#                                                본인      Unnamed: 0  \
#  0                                            NaN            연립주택
#  1                                             본인              상가
#  2                                            배우자              공장
#  3                                            배우자  아파트(전세(임\r차)권)
#  4   ▶ 부동산에 관한 규정이 준용되는 권리와 자동차·건설기계·선박 및 항공기(소계)         184,770
#  5                                            배우자             자동차
#  6                                            배우자             자동차
#  7                                            배우자              기타
#  8                                            배우자             자동차
#  9                                       ▶ 예금(소계)       1,549,967
#  10                                            본인             NaN
#  11                                           배우자             NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#  0                                            196.36m2    501,000     20,000
#  1     경상남도 창원시 성산구 대방동 골든프라자 대지 26.50\rm2 건물 125.30m2    141,709      2,245
#  2       경상남도 창원시 의창구 팔용동 대지 2,532.70m2 건물\r1,979.08m2  2,433,711          0
#  3                    서울특별시 종로구 명륜2가 아남아파트 건물 124.03m2    560,000     28,000
#  4                                                   0     15,610    169,160
#  5                              12년식 포터II 배기량(2,497cc)      3,830          0
#  6                               15년식 에쿠스 배기량(3,778cc)     34,810          0
#  7             금오엔지니어링 기계장치, 차량운반구, 공구와 기구비\r품, 시설장치 등     65,300          0
#  8                               20년식 카이엔 배기량(2,995cc)     80,830          0
#  9                                           4,560,183  1,255,709  4,854,441
#  10  경남은행 7,447(1 증가), 농협은행 153,666(21,854 증\r가), 농...    807,898  3,946,506
#  11  경남은행 25,713(459 감소), 농협은행 1,929(299,124\r감소), ...    720,078    612,287
#
#     Unnamed: 4 Unnamed: 5                                         Unnamed: 6  \
#  0           0    521,000                                               가액변동
#  1           0    143,954                                               가액변동
#  2      37,449  2,396,262                                      가액변동(건물가액 감소)
#  3           0    588,000                                            전세계약 연장
#  4         NaN        NaN                                                NaN
#  5         540      3,290                                               감가상각
#  6       4,620     30,190                                               감가상각
#  7           0     65,300                                            가액변동 없음
#  8      10,450     70,380                                               감가상각
#  9         NaN        NaN                                                NaN
#  10    630,408  4,123,996  - 세비 저축 및 생활비 지출, 금오\r엔지니어링(배우자 운영) 운영자금,\r가음정...
#  11    611,360    721,005                                                NaN
#
#      Unnamed: 7  Unnamed: 8
#  0          NaN         NaN
#  1          NaN         NaN
#  2          NaN         NaN
#  3          NaN         NaN
#  4          NaN         NaN
#  5          NaN         NaN
#  6          NaN         NaN
#  7          NaN         NaN
#  8          NaN         NaN
#  9          NaN         NaN
#  10         NaN         NaN
#  11         NaN         NaN  ,
#                                              장남  Unnamed: 0  \
#  0                                          NaN         NaN
#  1   ▶ 정치자금법에 따른 정치자금의 수입 및 지출을 위한 예금계좌의 예금(소계)      29,993
#  2                                           본인         NaN
#  3                                     ▶ 증권(소계)   4,138,020
#  4                                           본인       비상장주식
#  5                                          배우자       비상장주식
#  6                                           장남       비상장주식
#  7                                     ▶ 채권(소계)           0
#  8                                           본인         NaN
#  9                                     ▶ 채무(소계)     543,109
#  10                                         배우자        금융채무
#  11                                          장남        금융채무
#  12                                         총 계  11,529,621
#
#                                             Unnamed: 1 Unnamed: 2  Unnamed: 3  \
#  0   감소), 국민은행 69, 농협중앙회 1,081(4,570 감소),\r신한은행 2,8...     21,991       1,390
#  1                                              12,220          0      42,213
#  2                        (주)KEB하나은행 42,213(12,220 증가)     29,993      12,220
#  3                                             179,580    542,380   3,775,220
#  4                                  일진금속공업(주) 190,000주  1,551,540           0
#  5             일진금속공업(주) 280,000주, 일진단조공업(주) 30,000\r주  2,436,480      89,790
#  6                                   일진단조공업(주) 30,000주    150,000      89,790
#  7                                             150,000          0     150,000
#  8                                            사인간채권 증가          0     150,000
#  9                                             252,168    301,622     493,655
#  10       경남은행 1,536(549 증가), 신한은행 251,619(9,497 증\r가)    243,109     252,168
#  11                           농협중앙회 240,500(59,500 감소)    300,000           0
#  12                                          4,765,200  2,752,112  13,542,709
#
#                                Unnamed: 4 Unnamed: 5  \
#  0                                 13,941      9,440
#  1                                    NaN        NaN
#  2                                      0     42,213
#  3                                    NaN        NaN
#  4                                219,260  1,332,280
#  5                                323,120  2,203,150
#  6                                      0    239,790
#  7                                    NaN        NaN
#  8                                      0    150,000
#  9                                    NaN        NaN
#  10                               242,122    253,155
#  11                                59,500    240,500
#  12  증감액: 2,013,088천원\r(가액변동: -328,474천원)        NaN
#
#                                             Unnamed: 6  Unnamed: 7  Unnamed: 8
#  0   엔지니어링(배우자 운영) 운영자금,\r가음정공원조성사업 토지수용으로\r인한 토지보상...         NaN         NaN
#  1                                                 NaN         NaN         NaN
#  2                                            정치후원금 변동         NaN         NaN
#  3                                                 NaN         NaN         NaN
#  4                                             평가금액 변동         NaN         NaN
#  5                                                 NaN         NaN         NaN
#  6                                                 NaN         NaN         NaN
#  7                                                 NaN         NaN         NaN
#  8                                           사인간 채권 증가         NaN         NaN
#  9                                                 NaN         NaN         NaN
#  10             생활자금(마이너스통장), 금오엔지\r니어링 어음대출 일부상환 및 증가         NaN         NaN
#  11                                               일부상환         NaN         NaN
#  12                                                NaN         NaN         NaN  ,
#  Empty DataFrame
#  Columns: [- 11, Unnamed: 0]
#  Index: [],
#                                              소속  \
#  0                                          NaN
#  1                                          NaN
#  2                                         본인과의
#  3                                       재산의 종류
#  4                                           관계
#  5                                          NaN
#  6                                     ▶ 건물(소계)
#  7                                      다세대주택(전
#  8                                           본인
#  9                                      세(임차)권)
#  10                                     오피스텔(전세
#  11                                          본인
#  12                                      (임차)권)
#  13                                    사무실(전세(임
#  14                                          본인
#  15                                        차)권)
#  16                                    ▶ 예금(소계)
#  17                                         NaN
#  18                                         NaN
#  19                                          본인
#  20                                         NaN
#  21                                         NaN
#  22  ▶ 정치자금법에 따른 정치자금의 수입 및 지출을 위한 예금계좌의 예금(소계)
#  23                                          본인
#  24                                    ▶ 채권(소계)
#  25                                          본인
#  26                                         NaN
#  27                                         NaN
#
#                                           국회  Unnamed: 0       직위  \
#  0                                       NaN         NaN      NaN
#  1                                       NaN         NaN      NaN
#  2                                       NaN         NaN      NaN
#  3                           소재지 면적 등 권리의 명세         NaN     종전가액
#  4                                       NaN         NaN      NaN
#  5                                       NaN         NaN      NaN
#  6                                       NaN         NaN   52,000
#  7                                       NaN         NaN      NaN
#  8               대구광역시 동구 신서동 아가페 건물 19.83m2         NaN    2,000
#  9                                       NaN         NaN      NaN
#  10                서울특별시 강서구 가양동 가양글로벌퍼스트 대지         NaN      NaN
#  11                                      NaN         NaN   10,000
#  12                    28.12m2 건물 2,630.30m2         NaN      NaN
#  13                                      NaN         NaN      NaN
#  14            대구광역시 동구 용계동 테바빌딩 건물 247.56m2         NaN   40,000
#  15                                      NaN         NaN      NaN
#  16                                      NaN         NaN  162,068
#  17  농협은행 512(328 증가), 대구은행 224,978(80,314 증         NaN      NaN
#  18      가), 롯데손해보험 19,355(2,271 증가), 산림조합중앙         NaN      NaN
#  19                                      NaN         NaN  162,068
#  20      회 12, 새마을금고 39, 신한은행 76(1 증가), 한국카카         NaN      NaN
#  21                                오은행(주) 10         NaN      NaN
#  22                                      NaN         NaN   37,077
#  23                  농협은행 115,020(77,943 증가)         NaN   37,077
#  24                                      NaN         NaN   30,000
#  25                                    사인간채권         NaN   30,000
#  26                                      NaN         NaN      NaN
#  27                                      총 계         NaN  281,145
#
#                 국회의원                     성명 강대식 Unnamed: 1
#  0               NaN                        NaN  (단위 : 천원)
#  1               변동액                        NaN        NaN
#  2               NaN                        NaN        NaN
#  3               NaN                  현재가액 변동사유        NaN
#  4           증가액 감소액                        NaN        NaN
#  5   (실거래가격) (실거래가격)                        NaN        NaN
#  6          0 10,000                     42,000        NaN
#  7               NaN                        NaN        NaN
#  8               0 0                   2,000 월세        NaN
#  9               NaN                        NaN        NaN
#  10              NaN                        NaN        NaN
#  11              0 0  10,000 월세 (의정활동용 오피스텔 임대)        NaN
#  12              NaN                        NaN        NaN
#  13              NaN                        NaN        NaN
#  14         0 10,000    30,000 월세 (국회의원 사무실 임대)        NaN
#  15              NaN                        NaN        NaN
#  16   137,115 54,201                    244,982        NaN
#  17              NaN                        NaN        NaN
#  18              NaN                        NaN        NaN
#  19   137,115 54,201              244,982 급여 저축        NaN
#  20              NaN                        NaN        NaN
#  21              NaN                        NaN        NaN
#  22         77,943 0                    115,020        NaN
#  23         77,943 0      115,020 국회의원 정치자금 후원금        NaN
#  24              0 0                     30,000        NaN
#  25              0 0                30,000 변동없음        NaN
#  26              NaN             증감액: 150,857천원        NaN
#  27   215,058 64,201        432,002 (가액변동: 0천원)        NaN  ,
#                                                소속        Unnamed: 0  \
#  0                                            NaN               NaN
#  1                                       (단위 : 천원               NaN
#  2                                       본인과의\r관계            재산의 종류
#  3                                            NaN               NaN
#  4                                       ▶ 건물(소계)           352,000
#  5                                             본인    사무실(전세(임\r차)권)
#  6                                            배우자               아파트
#  7                                            배우자  다가구주택(전\r세(임차)권)
#  8                                             장녀  다세대주택(전\r세(임차)권)
#  9   ▶ 부동산에 관한 규정이 준용되는 권리와 자동차·건설기계·선박 및 항공기(소계)             1,500
#  10                                           배우자               자동차
#  11                                      ▶ 예금(소계)           587,845
#  12                                            본인               NaN
#
#                                             Unnamed: 1    Unnamed: 2  \
#  0                                                 NaN           NaN
#  1                                                 NaN           NaN
#  2                                     소재지 면적 등 권리의 명세          종전가액
#  3                                                 NaN  증가액\r(실거래가격)
#  4                                             115,000        10,000
#  5      경기도 안양시 만안구 안양동 PROJECT 240 TOWER 건물\r104.65m2        10,000
#  6            경기도 안양시만안구 만안구 석수동 코오롱하늘채  건\r물 117.61m2       332,000
#  7   서울특별시 성동구 마장동 대지 0.00m2 건물 0.00m2\r(대지 17.00m2...        10,000
#  8     서울특별시 성동구 마장동 삼성홈타운 건물 18.06m2\r(건물 18.06m2 증가)             0
#  9                                                   0         1,500
#  10                        2006년식 SM3  배기량(1,596cc) 감소         1,500
#  11                                            108,320        10,040
#  12  DB손해보험(주) 66,150(4,200 증가), 국민은행 3, 농협\r은행 1,9...        77,344
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
#  0            NaN        NaN        NaN        NaN
#  1            NaN        NaN        NaN        NaN
#  2            변동액       현재가액       변동사유        NaN
#  3   감소액\r(실거래가격)        NaN        NaN        NaN
#  4        457,000        NaN        NaN        NaN
#  5              0          0     10,000      변동 없음
#  6         85,000          0    417,000      가액 변동
#  7              0     10,000          0    전세계약 만료
#  8         30,000          0     30,000       전세계약
#  9              0        NaN        NaN        NaN
#  10             0      1,500          0     소유권 상실
#  11       686,125        NaN        NaN        NaN
#  12         6,215      5,248     78,311      급여 수입  ,
#  Empty DataFrame
#  Columns: [- 13, Unnamed: 0]
#  Index: [],
#  Empty DataFrame
#  Columns: [- 14, Unnamed: 0]
#  Index: [],
#                                            배우자 Unnamed: 0  \
#  0                                         NaN        NaN
#  1                                          장남        NaN
#  2                                          장녀        NaN
#  3  ▶ 정치자금법에 따른 정치자금의 수입 및 지출을 위한 예금계좌의 예금(소계)     54,301
#  4                                          본인        NaN
#  5                             ▶ 고지거부 및 등록제외사항          -
#  6                                           모        NaN
#  7                                         총 계    995,646
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#  0  17,962(1,668 증가), 농협손해보험 4,322(1,027 증가),\r동양생...    509,287    101,480
#  1                     (주)KEB하나은행 2, 국민은행 405(802 감소)      1,209        398
#  2  (주)KEB하나은행 200(200 증가), 농협중앙회 2, 신한은\r행 27(27 ...          5        227
#  3                                                  0     14,275     40,026
#  4                             농협은행 40,026(14,275 감소)     54,301          0
#  5                                                  -          -          -
#  6                                               고지거부          0          0
#  7                                            223,320     35,815  1,183,151
#
#                           Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7  \
#  0                             3,592    607,175      급여 수입         NaN
#  1                             1,200        407        NaN         NaN
#  2                                 0        232        NaN         NaN
#  3                               NaN        NaN        NaN         NaN
#  4                            14,275     40,026    의정활동 지출         NaN
#  5                               NaN        NaN        NaN         NaN
#  6                                 0          0       타인부양         NaN
# ...
#  9                                 0      5,000        변동없음
#  10                              NaN        NaN         NaN
#  11                                0     30,000        변동없음
#  12                              NaN        NaN         NaN
#  13                           36,008          0      독립생계유지
#  14                                0          0          혼인
#  15  증감액: 41,967천원\r(가액변동: 71,938천원)        NaN         NaN  ,
#  Empty DataFrame
#  Columns: [- 571, Unnamed: 0]
#  Index: [],
#  Empty DataFrame
#  Columns: [- 572, Unnamed: 0]
#  Index: [],
#                                                소속         Unnamed: 0  \
#  0                                            NaN                NaN
#  1                                       (단위 : 천원                NaN
#  2                                       본인과의\r관계             재산의 종류
#  3                                            NaN                NaN
#  4                                       ▶ 건물(소계)          2,597,063
#  5                                             본인                아파트
#  6                                             본인     아파트(전세(임\r차)권)
#  7                                             본인  근린생활시설\r(전세(임차)권)
#  8                                             본인   다세대주택(전\r세(임차)권)
#  9                                            배우자                아파트
#  10                                           배우자                사무실
#  11                                           배우자     아파트(전세(임\r차)권)
#  12  ▶ 부동산에 관한 규정이 준용되는 권리와 자동차·건설기계·선박 및 항공기(소계)              3,830
#  13                                           배우자                자동차
#  14                                           배우자                자동차
#  15                                      ▶ 예금(소계)            368,465
#
#                                             Unnamed: 1    Unnamed: 2  \
#  0                                                 NaN           NaN
#  1                                                 NaN           NaN
#  2                                     소재지 면적 등 권리의 명세          종전가액
#  3                                                 NaN  증가액\r(실거래가격)
#  4                                             404,000        35,000
#  5       서울특별시 송파구 문정동 올림픽훼밀리타운 건물\r117.59m2 중 58.79m2       493,500
#  6   경기도 용인시 기흥구 마북동 연원마을 삼호.벽산아파\r트 건물 0.00m2 (건물 ...        35,000
#  7                 경기도 용인시 기흥구 보정동 하이프라자 건물 165.80\rm2        30,000
#  8   경기도 용인시 기흥구 동백동 네이처팰리스 대지 89.30\rm2 건물 45.94m2...             0
#  9       서울특별시 송파구 문정동 올림픽훼밀리타운 건물\r117.59m2 중 58.79m2       493,500
#  10                서울특별시 송파구 문정동 문정역테라타워 건물 126.44\rm2       845,063
#  11                     서울특별시 송파구 가락동 헬리오시티 건물 84.99m2       700,000
#  12                                             38,300         3,830
#  13                         2010년식 아반떼 배기량(1,600cc) 감소         3,830
#  14                      2021년식 e-2008 SUV 배기량(0cc) 증가             0
#  15                                             21,046       231,542
#
#            Unnamed: 3      Unnamed: 4 Unnamed: 5 Unnamed: 6
#  0                NaN             NaN        NaN        NaN
#  1                NaN             NaN        NaN        NaN
#  2                변동액            현재가액       변동사유        NaN
#  3       감소액\r(실거래가격)             NaN        NaN        NaN
#  4          2,966,063             NaN        NaN        NaN
#  5            112,000               0    605,500     공시가격변동
#  6                  0          35,000          0     전세권 종료
#  7                  0               0     30,000       변동없음
#  8            180,000               0    180,000      신규전세권
#  9            112,000               0    605,500     공시가격변동
#  10                 0               0    845,063       변동없음
#  11                 0               0    700,000       변동없음
#  12            38,300             NaN        NaN        NaN
#  13                 0  3,830\r(1,000)          0         매도
#  14  38,300\r(49,400)               0     38,300         매입
#  15           157,969             NaN        NaN        NaN  ,
#                                              본인 Unnamed: 0  \
#  0                                          NaN        NaN
#  1                                          배우자        NaN
#  2                                           장남        NaN
#  3                                           장녀        NaN
#  4   ▶ 정치자금법에 따른 정치자금의 수입 및 지출을 위한 예금계좌의 예금(소계)     43,319
#  5                                           본인        NaN
#  6                                     ▶ 채무(소계)  1,841,910
#  7                                           본인       금융채무
#  8                                           본인     건물임대채무
#  9                                          배우자        NaN
#  10                                         배우자       금융채무
#  11                                         배우자     건물임대채무
#  12                                         배우자     건물임대채무
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#  0   10,804(6,620 증가), 삼성화재해상보험 39,000(3,000\r증가), ...     51,190     11,110
#  1   (주)KB손해보험 26,143(2,562 증가), 농협생명보험\r9,132, 농협은...    305,502      9,316
#  2                            (주)KEB하나은행 5,532(310 증가)      5,222        310
#  3                            (주)KEB하나은행 6,188(363 감소)      6,551        310
#  4                                                   0     34,767      8,552
#  5                               농협은행 8,552(34,767 감소)     43,319          0
#  6                                              28,857     51,062  1,819,705
#  7                              농협은행 20,083(20,506 감소)     40,589          0
#  8                      서울특별시 송파구 문정동 올림픽훼밀리타운 임대보증\r금    475,000          0
#  9                                            사인간채무 감소    246,000          0
#  10            농협은행 317,622(22,301 증가), 중소기업은행 300,000    595,321     28,857
#  11                        서울특별시 송파구 문정동 문정역테라타워 임대보증금     10,000          0
#  12                     서울특별시 송파구 문정동 올림픽훼밀리타운 임대보증\r금    475,000          0
#
#     Unnamed: 4 Unnamed: 5                         Unnamed: 6  Unnamed: 7  \
#  0         193     62,107  급여, 월 납입보험료, 저축예금입\r금, 전세보증금 사용 등         NaN
#  1     230,676     84,142                                NaN         NaN
#  2           0      5,532                                NaN         NaN
#  3         673      6,188                                NaN         NaN
#  4         NaN        NaN                                NaN         NaN
#  5      34,767      8,552                            정치자금 계좌         NaN
#  6         NaN        NaN                                NaN         NaN
#  7      20,506     20,083                             차입금 상환         NaN
#  8           0    475,000                               변동없음         NaN
#  9      24,000    222,000                             월 정기상환         NaN
#  10      6,556    617,622                          전세보증금 사용등         NaN
#  11          0     10,000                               변동없음         NaN
#  12          0    475,000                               변동없음         NaN
#
#      Unnamed: 8
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN  ,
#  Empty DataFrame
#  Columns: [- 573, Unnamed: 0]
#  Index: [],
#  Empty DataFrame
#  Columns: [- 574, Unnamed: 0]
#  Index: [],
#    ▶ 고지거부 및 등록제외사항 Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#  0             NaN        NaN          -          -          -
#  1               부        NaN       고지거부          0          0
#  2               모        NaN       고지거부          0          0
#  3             총 계  1,170,767    434,489    254,077  1,351,179
#
#                            Unnamed: 4  Unnamed: 5 Unnamed: 6
#  0                                  -         NaN        NaN
#  1                                  0         0.0     독립생계유지
#  2                                  0         0.0     독립생계유지
#  3  증감액: 180,412천원\r(가액변동: 224,000천원)         NaN        NaN  ,
#                                                소속  \
#  0                                            NaN
#  1                                            NaN
#  2                                           본인과의
#  3                                         재산의 종류
#  4                                             관계
#  5                                            NaN
#  6                                       ▶ 건물(소계)
#  7                                       아파트(전세(임
#  8                                             본인
#  9                                           차)권)
#  10  ▶ 부동산에 관한 규정이 준용되는 권리와 자동차·건설기계·선박 및 항공기(소계)
#  11                                        본인 자동차
#  12                                       배우자 자동차
#  13                                      ▶ 예금(소계)
#  14                                           NaN
#  15                                           NaN
#  16                                           NaN
#  17                                           NaN
#  18                                            본인
#  19                                           NaN
#  20                                           NaN
#  21                                           NaN
#  22                                           NaN
#  23                                           NaN
#  24                                           NaN
#  25                                           배우자
#  26                                           NaN
#  27                                           NaN
#
#                                              국회  Unnamed: 0       직위  \
#  0                                          NaN         NaN      NaN
#  1                                          NaN         NaN      NaN
#  2                                          NaN         NaN      NaN
#  3                              소재지 면적 등 권리의 명세         NaN     종전가액
#  4                                          NaN         NaN      NaN
#  5                                          NaN         NaN      NaN
#  6                                          NaN         NaN  340,000
#  7                 경기도 고양시 덕양구 행신동 무원9단지기산아파트 건         NaN      NaN
#  8                                          NaN         NaN  340,000
#  9                                   물 134.91m2         NaN      NaN
#  10                                         NaN         NaN   86,060
#  11                     2020년식 G80 배기량(3,470cc)         NaN   65,380
#  12                     2017년식 싼타페 배기량(1,995cc)         NaN   20,680
#  13                                         NaN         NaN  474,808
#  14        AIA생명보험주식회사 45,177(2,756 증가), DB손해보험         NaN      NaN
#  15      (주) 3,528(481 증가), 교보생명보험 113,778, 국민은         NaN      NaN
#  16    행 26,349(18,567 증가), 농협은행 19,804(2,571 증         NaN      NaN
#  17         가), 삼성생명보험 8,838(3,720 감소), 삼성화재해상보         NaN      NaN
#  18           험 37,828(1,119 증가), 신한라이프(오렌지라이프)         NaN  403,704
#  19  35,708(4,959 증가), 신한은행 134,038(58,197 증가),         NaN      NaN
#  20          씨티은행 11, 우리은행 54,369(45 증가), 유안타증권         NaN      NaN
#  21           1, 한국투자증권 2,352(541 증가), 현대해상화재보험         NaN      NaN
#  22                               8,368(929 증가)         NaN      NaN
#  23        (주)KB손해보험 4,068(1,180 증가), DB손해보험(주)         NaN      NaN
#  24   4,666(1,116 감소), 국민은행 1,933(1,460 증가), 삼성         NaN      NaN
#  25          화재해상보험 1,150(120 증가), 스탠다드차타드은행 8,         NaN   21,992
#  26         신한라이프(오렌지라이프) 11,864(4,068 증가), 현대해         NaN      NaN
#  27                         상화재보험 4,517(502 증가)         NaN      NaN
#
#                 국회의원              성명 이태규 Unnamed: 1
#  0               NaN                 NaN  (단위 : 천원)
#  1               변동액                 NaN        NaN
#  2               NaN                 NaN        NaN
#  3               NaN           현재가액 변동사유        NaN
#  4           증가액 감소액                 NaN        NaN
#  5   (실거래가격) (실거래가격)                 NaN        NaN
#  6               0 0             340,000        NaN
#  7               NaN                 NaN        NaN
#  8               0 0       340,000 변동 없음        NaN
#  9               NaN                 NaN        NaN
#  10         0 20,180              65,880        NaN
#  11         0 15,000        50,380 가액 변동        NaN
#  12          0 5,180        15,500 가액 변동        NaN
#  13    120,514 6,125             589,197        NaN
#  14              NaN                 NaN        NaN
#  15              NaN                 NaN        NaN
#  16              NaN                 NaN        NaN
#  17              NaN                 NaN        NaN
#  18     91,320 4,875             490,149        NaN
#  19              NaN                 NaN        NaN
#  20              NaN  급여 저축으로 인한 재산 증가 및        NaN
#  21              NaN    생활비 지출로 인한 재산 감소        NaN
#  22              NaN                 NaN        NaN
#  23              NaN                 NaN        NaN
#  24              NaN                 NaN        NaN
#  25      7,330 1,116              28,206        NaN
#  26              NaN                 NaN        NaN
#  27              NaN                 NaN        NaN  ,
#  Empty DataFrame
#  Columns: [- 576, Unnamed: 0]
#  Index: [],
#                                             장녀 Unnamed: 0  \
#  0                                         NaN        NaN
#  1                                          차녀        NaN
#  2  ▶ 정치자금법에 따른 정치자금의 수입 및 지출을 위한 예금계좌의 예금(소계)     19,278
#  3                                          본인        NaN
#  4                                    ▶ 증권(소계)     11,328
#  5                                          본인       상장주식
#  6                                    ▶ 채무(소계)     28,306
#  7                                          본인       금융채무
#  8                                         배우자       금융채무
#  9                                         총 계    903,168
#
#                  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#  0        42,056(14,905 증가)     29,923     17,256
#  1    신한은행 23,797(4,608 증가)     19,189      4,608
#  2                   27,403          0     46,681
#  3  농협중앙회 46,681(27,403 증가)     19,278     27,403
#  4                    3,115          0     14,443
#  5                  KT 472주     11,328      3,115
#  6                        0      9,832     18,474
#  7   현대캐피탈 17,574(9,832 감소)     27,406          0
#  8             현대해상화재보험 900        900          0
#  9                  151,032     16,473  1,037,727
#
#                            Unnamed: 4 Unnamed: 5  \
#  0                                134     47,045
#  1                                  0     23,797
#  2                                NaN        NaN
#  3                                  0     46,681
#  4                                NaN        NaN
#  5                                  0     14,443
#  6                                NaN        NaN
#  7                              9,832     17,574
#  8                                  0        900
#  9  증감액: 134,559천원\r(가액변동: -17,065천원)        NaN
#
#                               Unnamed: 6  Unnamed: 7  Unnamed: 8
#  0  급여 저축으로 인한 재산 증가 및\r생활비 지출로 인한 재산 감소         NaN         NaN
#  1                                   NaN         NaN         NaN
#  2                                   NaN         NaN         NaN
#  3                            후원금 모금액 증가         NaN         NaN
#  4                                   NaN         NaN         NaN
#  5                             주식 평가액 변동         NaN         NaN
#  6                                   NaN         NaN         NaN
#  7                            수당으로 일부 상환         NaN         NaN
#  8                             채무액 변동 없음         NaN         NaN
#  9                                   NaN         NaN         NaN  ,
#  ...]
